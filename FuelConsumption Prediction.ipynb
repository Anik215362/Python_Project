# %% [markdown]
# <a href="https://colab.research.google.com/github/Anik215362/Python_Project/blob/main/FuelConsumption%20Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data MIning/FuelConsumption.csv')

# %%
df
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %%
df.isnull().sum()
# Out:
# MODELYEAR                   0
# MAKE                        0
# MODEL                       0
# VEHICLECLASS                0
# ENGINESIZE                  0
# CYLINDERS                   0
# TRANSMISSION                0
# FUELTYPE                    0
# FUELCONSUMPTION_CITY        0
# FUELCONSUMPTION_HWY         0
# FUELCONSUMPTION_COMB        0
# FUELCONSUMPTION_COMB_MPG    0
# CO2EMISSIONS                0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1062    False
# 1063    False
# 1064    False
# 1065    False
# 1066    False
# Length: 1067, dtype: bool

# %%
df.shape
# Out:
# (1067, 13)

# %%
X = df[['ENGINESIZE']].values

# %%
y = df[['CO2EMISSIONS']].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
plt.scatter(X, y,marker='+', color='red')
plt.xlabel('ENGINESIZE')
plt.ylabel('CO2EMISSIONS')
plt.title('Chart')
# Out:
# Text(0.5, 1.0, 'Chart')

# %%
X_test
# Out:
# array([[3. ],
#        [1.4],
#        [2. ],
#        [2. ],
#        [4.6],
#        [3. ],
#        [2. ],
#        [1.8],
#        [3. ],
#        [2.4],
#        [2.4],
#        [3. ],
#        [2.4],
#        [5.2],
#        [2.5],
#        [2.5],
#        [1.6],
#        [4.4],
#        [3.5],
#        [2.4],
#        [6. ],
#        [2.5],
#        [3.7],
#        [3.5],
#        [3.7],
#        [3. ],
#        [1.2],
#        [5.5],
#        [1.6],
#        [2. ],
#        [3. ],
#        [5.2],
#        [3.5],
#        [5.3],
#        [4. ],
#        [5.3],
#        [6.2],
#        [1.5],
#        [4.2],
#        [3.3],
#        [3. ],
#        [6.3],
#        [2. ],
#        [3.6],
#        [3.7],
#        [2. ],
#        [1.4],
#        [1.4],
#        [2. ],
#        [3.4],
#        [1.6],
#        [5.7],
#        [4.3],
#        [6.2],
#        [2. ],
#        [3.7],
#        [2.5],
#        [5. ],
#        [3.7],
#        [1.6],
#        [2.4],
#        [2.7],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict(X_test)
# Out:
# array([[243.34753384],
#        [180.59365156],
#        [204.12635741],
#        [204.12635741],
#        [306.10141612],
#        [243.34753384],
#        [204.12635741],
#        [196.28212213],
#        [243.34753384],
#        [219.81482799],
#        [219.81482799],
#        [243.34753384],
#        [219.81482799],
#        [329.63412198],
#        [223.73694563],
#        [223.73694563],
#        [188.43788684],
#        [298.25718084],
#        [262.95812205],
#        [219.81482799],
#        [361.01106312],
#        [223.73694563],
#        [270.80235734],
#        [262.95812205],
#        [270.80235734],
#        [243.34753384],
#        [172.74941627],
#        [341.40047491],
#        [188.43788684],
#        [204.12635741],
#        [243.34753384],
#        [329.63412198],
#        [262.95812205],
#        [333.55623962],
#        [282.56871027],
#        [333.55623962],
#        [368.85529841],
#        [184.5157692 ],
#        [290.41294555],
#        [255.11388677],
# ...

# %%
plt.scatter(X, y,marker='+', color='red')
plt.xlabel('ENGINESIZE')
plt.ylabel('CO2EMISSIONS')
plt.title('Chart')
plt.plot(df['ENGINESIZE'],reg.predict(df[['ENGINESIZE']]))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"

# %%
reg.coef_
# Out:
# array([[39.22117643]])

# %%
reg.intercept_
# Out:
# array([125.68400456])

# %%
reg.score(X_test, y_test)
# Out:
# 0.7672977379444554
